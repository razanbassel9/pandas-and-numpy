# %% [markdown]
# #### 1. Write a Pandas program to create and display a one-dimensional array-like object containing an array of data using Pandas module.

# %%
import pandas as pd
arr1 = pd.Series([1, 2, 3, 4, 5])
print(arr1)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %% [markdown]
# #### 2. Write a Pandas program to convert a Panda module Series to Python list and it's type.

# %%
l_arr1=arr1.to_list()
print(l_arr1)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# #### 3. Write a Pandas program to compare the elements of the two Pandas Series.

# %%
arr2=pd.Series([1,4,3,4,6])
print(f"arr1: \n{arr1}")
print(f"\narr2: \n{arr2}")
# Out:
# arr1:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
#
# arr2:
# 0    1
# 1    4
# 2    3
# 3    4
# 4    6
# dtype: int64

# %%
print(f"Equal: \n{arr1==arr2}")
# Out:
# Equal:
# 0     True
# 1    False
# 2     True
# 3     True
# 4    False
# dtype: bool

# %% [markdown]
# #### 4. Write a Pandas program to change the data type of given a column or a Series.

# %%
arr3=pd.Series(["34","56","n","67","77"])
arr3=pd.to_numeric(arr3, errors='coerce')
print(arr3)
# Out:
# 0    34.0
# 1    56.0
# 2     NaN
# 3    67.0
# 4    77.0
# dtype: float64

# %% [markdown]
# #### 5. Write a Pandas program to get the first 3 rows of a given DataFrame. Sample Python dictionary data and list labels:
#     exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael',
#     'Matthew', 'Laura', 'Kevin', 'Jonas'],
#     'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
#     'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
#     'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
#     labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
#
# #### Expected Output:
#     First three rows of the data frame:
#     attempts name qualify score
#     a 1 Anastasia yes 12.5
#     b 3 Dima no 9.0
#     c 2 Katherine yes 16.5

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.25.2)

# %%
import numpy as np

# %%
exam_data = {
'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael',
'Matthew', 'Laura', 'Kevin', 'Jonas'],
'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']
}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

# %%
#print(exam_data['attempts'][1])

# %%
print("First three rows of the data frame: \nattempts name qualify score\n")
for i in range(0,3):
    print(f"{labels[i]} {exam_data['attempts'][i]} {exam_data['name'][i]} {exam_data['qualify'][i]} {exam_data['score'][i]}\n")
# Out:
# First three rows of the data frame:
# attempts name qualify score
#
# a 1 Anastasia yes 12.5
#
# b 3 Dima no 9
#
# c 2 Katherine yes 16.5

# %% [markdown]
# #### 6. Write a Pandas program to display the default index and set a column as an Index in a given dataframe.
# ![image.png](attachment:image.png)

# %%
x="street S00 VorVI name city date no"
df=pd.DataFrame([['Street1','S001','V','Alberto','Franco','15/05/2002',35],['Street2','S002','V','Gino','Mcneill','17/05/2002',32],
              ['Street3','S003','VI','Ryan','Parkes','16/02/1999',33],['Street4','S004','VI','Eesha','Hinton','25/09/1998',30],
              ['Street5','S005','V','Gino','Mcneill','11/05/2002',31],['Street6','S006','VI','David','Parkes','15/09/1997',32]],columns=x.split())
df
# Out:
#     street   S00 VorVI     name     city        date  no
# 0  Street1  S001     V  Alberto   Franco  15/05/2002  35
# 1  Street2  S002     V     Gino  Mcneill  17/05/2002  32
# 2  Street3  S003    VI     Ryan   Parkes  16/02/1999  33
# 3  Street4  S004    VI    Eesha   Hinton  25/09/1998  30
# 4  Street5  S005     V     Gino  Mcneill  11/05/2002  31
# 5  Street6  S006    VI    David   Parkes  15/09/1997  32

# %%
df.set_index("street", inplace=True)
df
# Out:
#           S00 VorVI     name     city        date  no
# street
# Street1  S001     V  Alberto   Franco  15/05/2002  35
# Street2  S002     V     Gino  Mcneill  17/05/2002  32
# Street3  S003    VI     Ryan   Parkes  16/02/1999  33
# Street4  S004    VI    Eesha   Hinton  25/09/1998  30
# Street5  S005     V     Gino  Mcneill  11/05/2002  31
# Street6  S006    VI    David   Parkes  15/09/1997  32

# %% [markdown]
# #### 7. Write a Pandas program to display the default index and set a column as an Index in a given dataframe and then reset the index
# ![image.png](attachment:image.png)

# %%
df.reset_index(inplace=True)
df
# Out:
#     street   S00 VorVI     name     city        date  no
# 0  Street1  S001     V  Alberto   Franco  15/05/2002  35
# 1  Street2  S002     V     Gino  Mcneill  17/05/2002  32
# 2  Street3  S003    VI     Ryan   Parkes  16/02/1999  33
# 3  Street4  S004    VI    Eesha   Hinton  25/09/1998  30
# 4  Street5  S005     V     Gino  Mcneill  11/05/2002  31
# 5  Street6  S006    VI    David   Parkes  15/09/1997  32

# %% [markdown]
# #### 8. Write a Pandas program to create a dataframe indexing by date and time.

# %%
df["time"]=["12:32","02:30","03:15","05:17","11:55","12:30"]
df
# Out:
#     street   S00 VorVI     name     city        date  no   time
# 0  Street1  S001     V  Alberto   Franco  15/05/2002  35  12:32
# 1  Street2  S002     V     Gino  Mcneill  17/05/2002  32  02:30
# 2  Street3  S003    VI     Ryan   Parkes  16/02/1999  33  03:15
# 3  Street4  S004    VI    Eesha   Hinton  25/09/1998  30  05:17
# 4  Street5  S005     V     Gino  Mcneill  11/05/2002  31  11:55
# 5  Street6  S006    VI    David   Parkes  15/09/1997  32  12:30

# %%
df.set_index(["date","time"], inplace=True)
df
# Out:
#                    street   S00 VorVI     name     city  no
# date       time
# 15/05/2002 12:32  Street1  S001     V  Alberto   Franco  35
# 17/05/2002 02:30  Street2  S002     V     Gino  Mcneill  32
# 16/02/1999 03:15  Street3  S003    VI     Ryan   Parkes  33
# 25/09/1998 05:17  Street4  S004    VI    Eesha   Hinton  30
# 11/05/2002 11:55  Street5  S005     V     Gino  Mcneill  31
# 15/09/1997 12:30  Street6  S006    VI    David   Parkes  32

# %% [markdown]
# #### 9. Write a Pandas program to create a dataframe and set a title or name of the index column.

# %%
data = {'Col'   : [1, 2, 3, 4],
        'name': ["razan", "rawan", "sahar", "malak"]}
dff = pd.DataFrame(data)
dff.set_index('name', inplace=True)
dff
# Out:
#        Col
# name
# razan    1
# rawan    2
# sahar    3
# malak    4

# %% [markdown]
# #### 10. Write a Pandas program to select a specific row of given series/dataframe by integer index.

# %%
df.iloc[0 : 3, 0 : 2]
# Out:
#                    street   S00
# date       time
# 15/05/2002 12:32  Street1  S001
# 17/05/2002 02:30  Street2  S002
# 16/02/1999 03:15  Street3  S003
